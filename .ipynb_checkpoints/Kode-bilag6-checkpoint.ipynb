# %% [markdown]
# # Case 3: Dansk Industri, del1
# *Anders Reinholt Sindberg (dks656) & Albert Neve Alsbjerg (kmp116)*

# %% [markdown]
# ## Klargøring og import
# Til databehandklingen vil følgende biblioteker blive brugt
# - **pandas** til at strukturere vores data
# - **numpy** til [...]
# - **matplotlib** til at plotte data
# - **afinn** til [...]
#
# De vil nu blive importeret:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from afinn import Afinn
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Delanalyse 2
# Først importeres bilag 6:

# %%
#bilaget importeres, ID sættes som indeks for datasættet. Dertil tilføjes datatyper til kolonnerne
df_mdb = pd.read_excel("bilag_6.xlsx",\
                       index_col=0, \
                       sheet_name="Medlemmernes Dag besvarelser")
#inspiceres
df_mdb
# Out:
#                  Spørgsmål 1. Hvordan går det \nhos jer, og hvad optager jer lige nu?  \
# Virksom-\nhedsID
# 3                 Virksomheden er en del af byggebranchen. Ingen...
# 4                 Det går rigtig godt, de får mange gode ordre. ...
# 5                 Det går godt. Det optager os, om vi kan blive ...
# 6                                                     Høj aktivitet
# 7                 Går rigtig godt, meget travlt. \nHar en masse ...
# ...                                                             ...
# 1655                                                            NaN
# 1659                                                            NaN
# 1668                                                            NaN
# 1678                                                            NaN
# 1687                                                            NaN
#
#                  Farvemarkering af hvordan det går  \
# Virksom-\nhedsID
# 3                                             Grøn
# 4                                             Grøn
# 5                                             Grøn
# 6                                             Grøn
# 7                                             Grøn
# ...                                            ...
# 1655                                           NaN
# 1659                                           NaN
# 1668                                           NaN
# 1678                                           NaN
# 1687                                           NaN
#
#                  Spørgsmål 2. Har I udfordringer, \nder fylder ekstra meget i øjeblikket?  \
# Virksom-\nhedsID
# 3                 Virksomhedens ejerleder, Maria, giver udtryk f...
# 4                 Deres største udfordringer pt. er at priserne ...
# 5                 Mangel på kvalificeret arbejdskraft. Vi mangle...
# 6                 Selv om der er mange igangværende sager, så er...
# 7                 Nej, alt går godt. \nEnetse udfordring har vær...
# ...                                                             ...
# 1655                                                            NaN
# 1659                                                            NaN
# 1668                                                            NaN
# 1678                                                            NaN
# 1687                                                            NaN
#
#                   Spørgsmål 2. Afkrydsning\nPolitisk interessevaretagelse: Administrative byrder  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning\nPolitisk interessevaretagelse: Adgang til kapital  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nPolitisk interessevaretagelse: Adgang til arbejdskraft  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                              True
# 6                                                              True
# 7                                                              True
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nPolitisk interessevaretagelse: Adgang til markeder  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nPolitisk interessevaretagelse: Digital omstilling  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nPolitisk interessevaretagelse: Grøn omstilling  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nCorona: Afskedigelser  \
# Virksom-\nhedsID
# 3                                                            False
# 4                                                            False
# 5                                                            False
# 6                                                            False
# 7                                                            False
# ...                                                            ...
# 1655                                                         False
# 1659                                                         False
# 1668                                                         False
# 1678                                                         False
# 1687                                                         False
#
#                   Spørgsmål 2. Afkrydsning \nCorona: Lønkompensation og hjælpepakker  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nCorona: Udenlandsk arbejdskraft  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nOK/Personalejuridisk: Elever/lærlinge  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nOK/Personalejuridisk: Overenskomster  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                   Spørgsmål 2. Afkrydsning \nOK/Personalejuridisk: Udenlandsk arbejdskraft  \
# Virksom-\nhedsID
# 3                                                             False
# 4                                                             False
# 5                                                             False
# 6                                                             False
# 7                                                             False
# ...                                                             ...
# 1655                                                          False
# 1659                                                          False
# 1668                                                          False
# 1678                                                          False
# 1687                                                          False
#
#                  Spørgsmål 3: \nHvordan kan vi i DI gøre det endnu bedre for dig og din virksomhed?
# Virksom-\nhedsID
# 3                 DI's jurahjælp er ikke så meget til hjælp. (ju...
# 4                 Det er godt tilfreds med deres medlemsskab og ...
# 5                 Vi skal gøre en ekstra indsats for at få flere...
# 6                 Har brugt medlemsskabet i Dansk Træ meget. Og ...
# 7                 Sætter stor nyhedsbrevene. Rigtig stor fornøje...
# ...                                                             ...
# 1655                                                            NaN
# 1659                                                            NaN
# 1668                                                            NaN
# 1678                                                            NaN
# 1687                                                            NaN
#
# [1700 rows x 16 columns]

# %% [markdown]
# ### Hvor mange nævner covid?
# Dette undersøger vi på tværs af alle svar kategorier.

# %%
test = "hej med dig. aer qe23 !123! aw3-aw3"
print(word_tokenize(test))
# Out:
# ['hej', 'med', 'dig', '.', 'aer', 'qe23', '!', '123', '!', 'aw3-aw3']

# %%
def check_covic(row):
    coivd_word= ["covid",
                'covid-19',
                'corona']
    result = 0
    for column in df_mdb:
        token_list = word_tokenize(row[column])
        #if any(word in 'some one long two phrase three' for word in list_):
        
#for column in df_mdb:
#    print(column)
# Out:
# Spørgsmål 1. Hvordan går det
# hos jer, og hvad optager jer lige nu?
# Farvemarkering af hvordan det går
# Spørgsmål 2. Har I udfordringer,
# der fylder ekstra meget i øjeblikket?
# Spørgsmål 2. Afkrydsning
# Politisk interessevaretagelse: Administrative byrder
# Spørgsmål 2. Afkrydsning
# Politisk interessevaretagelse: Adgang til kapital
# Spørgsmål 2. Afkrydsning
# Politisk interessevaretagelse: Adgang til arbejdskraft
# Spørgsmål 2. Afkrydsning
# Politisk interessevaretagelse: Adgang til markeder
# Spørgsmål 2. Afkrydsning
# Politisk interessevaretagelse: Digital omstilling
# Spørgsmål 2. Afkrydsning
# Politisk interessevaretagelse: Grøn omstilling
# Spørgsmål 2. Afkrydsning
# Corona: Afskedigelser
# Spørgsmål 2. Afkrydsning
# Corona: Lønkompensation og hjælpepakker
# Spørgsmål 2. Afkrydsning
# Corona: Udenlandsk arbejdskraft
# Spørgsmål 2. Afkrydsning
# OK/Personalejuridisk: Elever/lærlinge
# Spørgsmål 2. Afkrydsning
# OK/Personalejuridisk: Overenskomster
# Spørgsmål 2. Afkrydsning
# OK/Personalejuridisk: Udenlandsk arbejdskraft
# Spørgsmål 3:
# Hvordan kan vi i DI gøre det endnu bedre for dig og din virksomhed?
